# %%
# extracting skills with trace
import requests
import json

output_path = 'Data\OutputPDF\Profile_skills.json'

url = "https://emsiservices.com/skills/versions/latest/extract/trace"

querystring = {"language":"en"}

payload = "{ \"text\": \"... Great candidates also have\\n\\n Experience with a particular JS MV* framework (we happen to use React)\\n Experience working with databases\\n Experience with AWS\\n Familiarity with microservice architecture\\n Familiarity with modern CSS practices, e.g. LESS, SASS, CSS-in-JS ...\", \"confidenceThreshold\": 0.6 }"
headers = {
    'Authorization': "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..XUUeH6a_fU2VwbQPyL5SqCzKLIntnsoKxQefQnQfAWjHo_7VtUtmvIpVQ-zwuyylqBCQVDsQlpt71xyRwXllU1r0JJlcFgIX6MAlyGqC26vcY8RArRKGQJfH5l418zKl9Rinkg3uQoGJEwijGWhYU_J0Vls8yLOcF6oCquO8evB8i6gkzs4SX3IbLusjdab0fDHeX3XbsfHxyIpDPLrDInzYAvDvLl3fe-LrRZ10Xu1RdsUkfwoEeMtvzal5mEJcAwcOn5xNdDcKFFwM-8z6o4MEskC0_3xOAsVIQwvqxs22NUErkz3TS5M8FrMFDHW-Wxdg3ahSIKfOnM-HbH0W1g",
    'Content-Type': "application/json"
    }

response = requests.request("POST", url, data=payload, headers=headers, params=querystring)

with open(output_path, "w") as file:
    file.write(response.text)
print(response.text)
# Out:
# {"attributions": [{"name": "Wikipedia", "text": "Wikipedia extracts are distributed under the CC BY-SA license (https://creativecommons.org/licenses/by-sa/3.0/)"}], "data": {"normalizedText": null, "skills": [{"confidence": 1.0, "skill": {"description": "Microservice architecture \u2013 a variant of the service-oriented architecture (SOA) structural style \u2013 arranges an application as a collection of loosely coupled services. In a microservices architecture, services are fine-grained and the protocols are lightweight.", "descriptionSource": "https://en.wikipedia.org/wiki/Microservices", "id": "KSZX7YZWNR5IDR1I2VMZ", "infoUrl": "https://lightcast.io/open-skills/skills/KSZX7YZWNR5IDR1I2VMZ", "name": "Microservices", "tags": [{"key": "wikipediaExtract", "value": "Microservice architecture \u2013 a variant of the service-oriented architecture (SOA) structural style \u2013 arranges an application as a collection of loosely coupled services. In a microservices architecture, services ar
# ...
